# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# ART20_score = pd.read_csv('HEDIS_data2020\ART\ART_score - Copy.csv')
# if 'RExcl' in ART20_score.columns:
#     ART20_score_modified = ART20_score[(ART20_score.Epop==1) & (ART20_score.RExcl==0)]
# else:
#     ART20_score_modified = ART20_score[(ART20_score.Epop==1)]
# ART20_score_mod = ART20_score_modified[['MemID','Num']]
# ART20_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=False)

# ART20_diag = pd.read_csv('HEDIS_data2020\ART\ART_diag.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_member_en = pd.read_csv('HEDIS_data2020\ART\ART_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_member_gm = pd.read_csv('HEDIS_data2020\ART\ART_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_mmdf = pd.read_csv('HEDIS_data2020\ART\ART_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_obs = pd.read_csv('HEDIS_data2020\ART\ART_obs.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_pharm = pd.read_csv('HEDIS_data2020\ART\ART_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_visit = pd.read_csv('HEDIS_data2020\ART\ART_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
# ART20_merged = ART20_diag.append([ART20_member_en,ART20_member_gm,ART20_mmdf,ART20_obs,ART20_pharm,ART20_visit],sort=False)

# %%
# BCS18_score = pd.read_csv('HEDIS_data2018\BCS\BCS_score.csv')
# if 'RExcl' in BCS18_score.columns:
#     BCS18_score_modified = BCS18_score[(BCS18_score.Epop==1) & (BCS18_score.RExcl==0)]
# else:
#     BCS18_score_modified = BCS18_score[(BCS18_score.Epop==1)]
# BCS18_score_mod = BCS18_score_modified[['MemID','Num']]
# BCS18_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=True)
# print(BCS18_score_mod.shape)

# BCS18_member_en = pd.read_csv('HEDIS_data2018\BCS\BCS_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS18_member_gm = pd.read_csv('HEDIS_data2018\BCS\BCS_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS18_visit = pd.read_csv('HEDIS_data2018\BCS\BCS_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
# print(BCS18_visit.columns)
# BCS18_merged = BCS18_member_en.append([BCS18_member_gm,BCS18_visit],sort=False)
BCS18_merged.drop_duplicates(inplace=True)
# BCS18_merged.DOB.unique()

# BCS18_merged['DOB'] = BCS18_merged.DOB.astype('str')
# BCS18_merged[['DOB','waste']] = BCS18_merged['DOB'].str.split(".", expand = True)
# BCS18_merged.drop('waste', axis = 1)

# %%
# BCS19_score = pd.read_csv('HEDIS_data2019\BCS\BCS_score.csv')
# if 'RExcl' in BCS19_score.columns:
#     BCS19_score_modified = BCS19_score[(BCS19_score.Epop==1) & (BCS19_score.RExcl==0)]
# else:
#     BCS19_score_modified = BCS19_score[(BCS19_score.Epop==1)]
# BCS19_score_mod = BCS19_score_modified[['MemID','Num']]
# BCS19_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=True)
# print(BCS19_score_mod.shape)

# BCS19_member_en = pd.read_csv('HEDIS_data2019\BCS\BCS_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS19_member_gm = pd.read_csv('HEDIS_data2019\BCS\BCS_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS19_mmdf = pd.read_csv('HEDIS_data2019\BCS\BCS_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS19_pharm = pd.read_csv('HEDIS_data2019\BCS\BCS_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# BCS19_visit = pd.read_csv('HEDIS_data2019\BCS\BCS_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
# print(BCS19_visit.columns)
# BCS19_merged = BCS19_member_en.append([BCS19_member_gm,BCS19_mmdf,BCS19_pharm,BCS19_visit],sort=False)
# BCS19_merged.drop_duplicates(inplace=True)

# BCS19_merged.DOB.unique()

BCS19_merged['DOB'] = BCS19_merged.DOB.astype('str')
BCS19_merged[['DOB','waste']] = BCS19_merged['DOB'].str.split(".", expand = True)
BCS19_merged.drop('waste', axis = 1)
# Out:
#          MemID   StartDate  FinishDate Dental Drug MHInpt MHDN MHAMB CDInpt  \
# 0        95000  19901007.0  20191231.0      N    Y      N    N     Y      Y
# 1        95005  19691226.0  20180621.0      N    N      Y    Y     Y      N
# 2        95006  19560813.0  20161231.0      Y    Y      Y    Y     Y      Y
# 3        95006         NaN         NaN      Y    Y      Y    Y     Y      Y
# 4        95007  19670801.0  20161231.0      N    N      N    Y     N      N
# ...        ...         ...         ...    ...  ...    ...  ...   ...    ...
# 312871  162802         NaN         NaN    NaN  NaN    NaN  NaN   NaN    NaN
# 312872  162802         NaN         NaN    NaN  NaN    NaN  NaN   NaN    NaN
# 312873  162802         NaN         NaN    NaN  NaN    NaN  NaN   NaN    NaN
# 312874  162802         NaN         NaN    NaN  NaN    NaN  NaN   NaN    NaN
# 312875  162802         NaN         NaN    NaN  NaN    NaN  NaN   NaN    NaN
#
# ...

# %%
BCS20_score = pd.read_csv('HEDIS_data2020\BCS\BCS_score.csv')
if 'RExcl' in BCS20_score.columns:
    BCS20_score_modified = BCS20_score[(BCS20_score.Epop==1) & (BCS20_score.RExcl==0)]
else:
    BCS20_score_modified = BCS20_score[(BCS20_score.Epop==1)]
BCS20_score_mod = BCS20_score_modified[['MemID','Num']]
BCS20_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=True)
print(BCS20_score_mod.shape)

BCS20_diag = pd.read_csv('HEDIS_data2020\BCS\BCS_diag.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_lab = pd.read_csv('HEDIS_data2020\BCS\BCS_lab.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_lishist = pd.read_csv('HEDIS_data2020\BCS\BCS_lishist.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_member_en = pd.read_csv('HEDIS_data2020\BCS\BCS_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_member_gm = pd.read_csv('HEDIS_data2020\BCS\BCS_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
print(BCS20_member_gm.DOB)
BCS20_mmdf = pd.read_csv('HEDIS_data2020\BCS\BCS_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_obs = pd.read_csv('HEDIS_data2020\BCS\BCS_obs.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_pharm = pd.read_csv('HEDIS_data2020\BCS\BCS_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_proc = pd.read_csv('HEDIS_data2020\BCS\BCS_proc.csv',skipinitialspace=True).dropna(axis=1, how='all')
BCS20_visit = pd.read_csv('HEDIS_data2020\BCS\BCS_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
print(BCS20_visit.columns)
BCS20_merged = BCS20_diag.append([BCS20_lab,BCS20_lishist,BCS20_member_en,BCS20_member_gm,BCS20_mmdf,BCS20_obs,BCS20_pharm,BCS20_proc,BCS20_visit],sort=False)
BCS20_merged.drop_duplicates(inplace=True)

# %%
# ART18_score_mod = pd.read_csv('HEDIS_data2018\ART\ART18_score_modified.csv')
# ART18_score_mod.MemID.nunique()
# ART18_member_en = pd.read_csv('HEDIS_data2018\ART\ART_member_en.csv')
# ART18_member_gm = pd.read_csv('HEDIS_data2018\ART\ART_member_gm.csv')
# ART18_pharm = pd.read_csv('HEDIS_data2018\ART\ART_pharm.csv')
# ART18_visit = pd.read_csv('HEDIS_data2018\ART\ART_visit.csv')
# ART18_merged = ART18_member_en.append([ART18_member_gm,ART18_pharm,ART18_visit],sort=False)
# ART18_merged['Meas']='ART'

# ART19_member_en = pd.read_csv('HEDIS_data2019\ART\ART_member_en.csv')
# ART19_member_gm = pd.read_csv('HEDIS_data2019\ART\ART_member_gm.csv')
# ART19_mmdf = pd.read_csv('HEDIS_data2019\ART\ART_mmdf.csv')
# ART19_pharm = pd.read_csv('HEDIS_data2019\ART\ART_pharm.csv')
# ART19_visit = pd.read_csv('HEDIS_data2010\ART\ART_visit.csv')
# ART19_merged = ART19_member_en.append([ART19_member_gm,ART19_mmdf,ART19_pharm,ART19_visit],sort=False)
# ART19_merged['Meas']='ART'

# %%
CDC18_score = pd.read_csv('HEDIS_data2018\CDC\CDC_score.csv')
if 'RExcl' in CDC18_score.columns:
    CDC18_score_modified = CDC18_score[(CDC18_score.Epop==1) & (CDC18_score.RExcl==0)]
else:
    CDC18_score_modified = CDC18_score[(CDC18_score.Epop==1)]
CDC18_score_mod = CDC18_score_modified[['MemID','Num']]
CDC18_score_mod = CDC18_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=False)
print(CDC18_score_mod.shape)

CDC18_lab = pd.read_csv('HEDIS_data2018\CDC\CDC_lab.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC18_member_en = pd.read_csv('HEDIS_data2018\CDC\CDC_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC18_member_gm = pd.read_csv('HEDIS_data2018\CDC\CDC_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC18_pharm = pd.read_csv('HEDIS_data2018\CDC\CDC_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC18_visit = pd.read_csv('HEDIS_data2018\CDC\CDC_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC18_merged = CDC18_lab.append([CDC18_member_en,CDC18_member_gm,CDC18_mmdf,CDC18_obs,CDC18_pharm,CDC18_visit],sort=False)
CDC18_merged = CDC18_merged.drop_duplicates()

# %%
CDC19_score = pd.read_csv('HEDIS_data2019\CDC\CDC_score.csv')
if 'RExcl' in CDC19_score.columns:
    CDC19_score_modified = CDC19_score[(CDC19_score.Epop==1) & (CDC19_score.RExcl==0)]
else:
    CDC19_score_modified = CDC19_score[(CDC19_score.Epop==1)]
CDC19_score_mod = CDC19_score_modified[['MemID','Num']]
CDC19_score_mod = CDC19_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=False)

CDC19_lab = pd.read_csv('HEDIS_data2019\CDC\CDC_lab.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_member_en = pd.read_csv('HEDIS_data2019\CDC\CDC_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_member_gm = pd.read_csv('HEDIS_data2019\CDC\CDC_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_mmdf = pd.read_csv('HEDIS_data2019\CDC\CDC_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_pharm = pd.read_csv('HEDIS_data2019\CDC\CDC_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_visit = pd.read_csv('HEDIS_data2019\CDC\CDC_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
CDC19_merged = CDC19_lab.append([CDC19_member_en,CDC19_member_gm,CDC19_mmdf,CDC19_pharm,CDC19_visit],sort=False)
CDC19_merged = CDC19_merged.drop_duplicates()

# %%
# CDC20_score = pd.read_csv('HEDIS_data2020\CDC\CDC_score.csv')
# if 'RExcl' in CDC20_score.columns:
#     CDC20_score_modified = CDC20_score[(CDC20_score.Epop==1) & (CDC20_score.RExcl==0)]
# else:
#     CDC20_score_modified = CDC20_score[(CDC20_score.Epop==1)]
# CDC20_score_mod = CDC20_score_modified[['MemID','Num']]
# CDC20_score_mod = CDC20_score_mod.drop_duplicates(subset='MemID', keep='first', inplace=False)

# CDC20_diag = pd.read_csv('HEDIS_data2020\CDC\CDC_diag.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_lab = pd.read_csv('HEDIS_data2020\CDC\CDC_lab.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_lishist = pd.read_csv('HEDIS_data2020\CDC\CDC_lishist.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_member_en = pd.read_csv('HEDIS_data2020\CDC\CDC_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_member_gm = pd.read_csv('HEDIS_data2020\CDC\CDC_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_mmdf = pd.read_csv('HEDIS_data2020\CDC\CDC_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_obs = pd.read_csv('HEDIS_data2020\CDC\CDC_obs.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_pharm = pd.read_csv('HEDIS_data2020\CDC\CDC_pharm.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_proc = pd.read_csv('HEDIS_data2020\CDC\CDC_proc.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_visit = pd.read_csv('HEDIS_data2020\CDC\CDC_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
# CDC20_visit.columns
# CDC20_merged = CDC20_diag.append([CDC20_lab,CDC20_lishist,CDC20_member_en,CDC20_member_gm,CDC20_mmdf,CDC20_obs,CDC20_pharm,CDC20_proc,CDC20_visit],sort=False)
# CDC20_merged = CDC20_merged.drop_duplicates()

# %%
CCS20_diag = pd.read_csv('HEDIS_data2020\CCS\CCS_diag.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_lab = pd.read_csv('HEDIS_data2020\CCS\CCS_lab.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_member_en = pd.read_csv('HEDIS_data2020\CCS\CCS_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_member_gm = pd.read_csv('HEDIS_data2020\CCS\CCS_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_obs = pd.read_csv('HEDIS_data2020\CCS\CCS_obs.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_proc = pd.read_csv('HEDIS_data2020\CCS\CCS_proc.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_visit = pd.read_csv('HEDIS_data2020\CCS\CCS_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
CCS20_merged = CCS20_diag.append([CCS20_lab,CCS20_member_en,CCS20_member_gm,CCS20_obs,CCS20_proc,CCS20_visit],sort=False)
CCS20_merged['Meas']='CCS'

# %%
MRP20_member_en = pd.read_csv('HEDIS_data2020\MRP\MRP_member_en.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_member_gm = pd.read_csv('HEDIS_data2020\MRP\MRP_member_gm.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_mmdf = pd.read_csv('HEDIS_data2020\MRP\MRP_mmdf.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_obs = pd.read_csv('HEDIS_data2020\MRP\MRP_obs.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_proc = pd.read_csv('HEDIS_data2020\MRP\MRP_proc.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_visit = pd.read_csv('HEDIS_data2020\MRP\MRP_visit.csv',skipinitialspace=True).dropna(axis=1, how='all')
MRP20_merged = MRP20_member_en.append([MRP20_member_gm,MRP20_mmdf,MRP20_obs,MRP20_proc,MRP20_visit],sort=False)
MRP20_merged['Meas']='MRP'

# %%
# H20_merged = ART20_merged.append([BCS20_merged,CCS20_merged,CDC20_merged,MRP20_merged],sort=False)

# %%
# Hedis = pd.DataFrame(CDC20_merged.MemID.unique())
CDC20_score_mod.head()

# %%
#no of ip and op visits
Meas = BCS1_merged
ipop=pd.DataFrame()
size=Meas.MemID.unique()
idv=[]
ip=[]
op=[]
diag=[]
proc=[]
ipval=0
opval=0
dc=0
pc=0

for i in size:
    a=Meas.Date_Adm[Meas.MemID==i].count()
    ad=Meas.loc[Meas.MemID == i,'Date_Adm']
    
    dfp = Meas[Meas.MemID==i]
    dc = (dfp['Diag_I_1'].append(dfp['Diag_I_2']).append(dfp['Diag_I_3']).append(dfp['Diag_I_4']).append(dfp['Diag_I_5']).append(dfp['Diag_I_6']).append(dfp['Diag_I_7']).append(dfp['Diag_I_8']).append(dfp['Diag_I_9']).append(dfp['Diag_I_10'])).nunique()
    pc = (dfp['Proc_I_1'].append(dfp['Proc_I_2']).append(dfp['Proc_I_3']).append(dfp['Proc_I_4']).append(dfp['Proc_I_5']).append(dfp['Proc_I_6'])).nunique()

    #gen=ART.Gender[ART.MemID == i]
    if(a>=1):
        ipval=a
    opval=ad.isnull().sum()
    idv.append(i)
    ip.append(ipval)
    op.append(opval)
    diag.append(dc)
    proc.append(pc)

ipop['MemID']=idv   
ipop['No_Ip_visits']=ip
ipop['No_Op_visits']=op
ipop['Diag_count']=diag
ipop['Proc_count']=proc

# %%
BCS18_merged.MemID.nunique()

# %%
plt.hist(ipop.No_Ip_visits, bins = 10)
plt.show()

# %%
plt.hist(ipop.No_Op_visits, bins = 10)
plt.show()

# %%
plt.hist(ipop.Diag_count, bins = 10)
plt.show()

# %%
plt.hist(ipop.Proc_count, bins = 10)
plt.show()

# %%
BCS19_merged['DOB'] =  pd.to_datetime(BCS19_merged['DOB'])
now = pd.to_datetime('now')
BCS19_merged['Age'] = now.year - BCS19_merged.DOB.dt.year

df_age = pd.DataFrame(BCS19_merged.groupby(['MemID','Age']).size().reset_index(name='count'))
df_age['Age'] = df_age.Age.astype('int')
df_age = df_age[['MemID','Age']]
# df_age.Age

# %%
CDC20_merged['DOB'] =  pd.to_datetime(CDC20_merged['DOB'])
now = pd.to_datetime('now')
CDC20_merged['Age'] = now.year - CDC20_merged.DOB.dt.year

df_age = pd.DataFrame(CDC20_merged.groupby(['MemID','Age']).size().reset_index(name='count'))
df_age['Age'] = df_age.Age.astype('int')
df_age = df_age[['MemID','Age']]

# %%
# gend = pd.DataFrame(pd.crosstab(H20_merged.MemID, H20_merged.Gender))
# gend[(gend.F!=0) & (gend.M!=0)]
# gend = pd.DataFrame(pd.crosstab(H20_merged.MemID, H20_merged.Gender))

# pd.crosstab(H20_merged.MemID, H20_merged.DOB,margins=True)
# H20_merged.Payer.nunique()

# H20_merged[['MemID','Gender']].head()
# df_gen = pd.DataFrame(BCS18_merged.groupby(['MemID','Gender']).size().reset_index(name='count'))
df_gen = df_gen[['MemID','Gender']]
df_gen.head(10)
# Out:
#    MemID Gender
# 0  95000      M
# 1  95001      F
# 2  95002      F
# 3  95003      F
# 4  95004      F
# 5  95005      F
# 6  95006      F
# 7  95007      F
# 8  95008      F
# 9  95009      F

# %%
df_gen = pd.DataFrame(BCS19_merged.groupby(['MemID','Gender']).size().reset_index(name='count'))
df_gen = df_gen[['MemID','Gender']]

# %%
# final_BCS18 = BCS18_score_mod.merge(df_gen, on='MemID', how='left')
# final_BCS18 = final_BCS18.merge(df_age, on='MemID', how='left')
# final_BCS18 = final_BCS18.merge(ipop, on='MemID', how='left')
Gender = {'M': 1,'F': 2}
final_BCS18.Gender = [Gender[item] for item in final_BCS18.Gender]
# final_BCS18.head

# %%
# final_BCS19 = BCS19_score_mod.merge(df_gen, on='MemID', how='left')
# final_BCS19 = final_BCS19.merge(df_age, on='MemID', how='left')
# final_BCS19 = final_BCS19.merge(ipop, on='MemID', how='left')
Gender = {'M': 1,'F': 2}
final_BCS19.Gender = [Gender[item] for item in final_BCS19.Gender]
# final_BCS18.head

# %%
# final_CDC19 = CDC19_score_mod.merge(df_gen, on='MemID', how='left')
# final_CDC19 = final_CDC19.merge(df_age, on='MemID', how='left')
# final_CDC19 = final_CDC19.merge(ipop, on='MemID', how='left')
Gender = {'M': 1,'F': 2}
final_CDC19.Gender = [Gender[item] for item in final_CDC19.Gender]
# final_CDC19.shape

# %%
# final_CDC20 = CDC20_score_mod.merge(df_gen, on='MemID', how='left')
# final_CDC20 = final_CDC20.merge(df_age, on='MemID', how='left')
# final_CDC20 = final_CDC20.merge(ipop, on='MemID', how='left')
# Gender = {'M': 1,'F': 2}
# final_CDC20.Gender = [Gender[item] for item in final_CDC20.Gender]
# final_CDC20.head()
CDC20_score_mod.head()

# %%
final_BCS19.to_csv(r'HEDIS_data2019\BCS\final_BCS19.csv', index=False)
# final_CDC19.to_csv(r'HEDIS_data2019\CDC\final_CDC19.csv', index=False)
# final_CDC20.to_csv(r'HEDIS_data2020\CDC\final_CDC20.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.tree import plot_tree

# %%
# Function importing Dataset 
def importdata(): 
    balance_data = pd.read_excel('HEDIS_data2020\ART\ART_score.xlsx') 

    # Printing the dataswet shape
    print ("Dataset Length: ", len(balance_data)) 
    print ("Dataset Shape: ", balance_data.shape) 
      
    Gender = {'M': 1,'F': 2} 
    balance_data.Gender = [Gender[item] for item in balance_data.Gender]  
    # Printing the dataset obseravtions 
    print ("Dataset: ",balance_data.head()) 
    return balance_data

# Function to split the dataset 
def splitdataset(balance_data): 
  
    # Separating the target variable 
    X = balance_data.values[:, 1:7] 
    Y = balance_data.values[:, 8] 
  
    # Splitting the dataset into train and test 
    X_train, X_test, y_train, y_test = train_test_split(  
    X, Y, test_size = 0.3, random_state = 100) 
    
    return X, Y, X_train, X_test, y_train, y_test

# Function to perform training with giniIndex. 
def train_using_gini(X_train, X_test, y_train): 
  
    # Creating the classifier object 
    clf_gini = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5) 
  
    # Performing training 
    clf_gini.fit(X_train, y_train) 
    return clf_gini 

# Function to perform training with entropy. 
def tarin_using_entropy(X_train, X_test, y_train): 
  
    # Decision tree with entropy 
    clf_entropy = DecisionTreeClassifier( 
            criterion = "entropy", random_state = 100, 
            max_depth = 3, min_samples_leaf = 5) 
  
    # Performing training 
    clf_entropy.fit(X_train, y_train) 
    return clf_entropy 

# Function to make predictions 
def prediction(X_test, clf_object): 
  
    # Predicton on test with giniIndex 
    y_pred = clf_object.predict(X_test) 
    print("Predicted values:") 
    print(y_pred) 
    return y_pred 
      
# Function to calculate accuracy 
def cal_accuracy(y_test, y_pred): 
      
    print("Confusion Matrix: ", 
        confusion_matrix(y_test, y_pred)) 
      
    print ("Accuracy : ", 
    accuracy_score(y_test,y_pred)*100) 
      
    print("Report : ", 
    classification_report(y_test, y_pred)) 
    
# Driver code 
def main(): 
      
    # Building Phase 
    data = importdata() 
    X, Y, X_train, X_test, y_train, y_test = splitdataset(data) 
    clf_gini = train_using_gini(X_train, X_test, y_train) 
    clf_entropy = tarin_using_entropy(X_train, X_test, y_train) 
      
    # Operational Phase 
    print("Results Using Gini Index:") 
      
    # Prediction using gini 
    y_pred_gini = prediction(X_test, clf_gini) 
    cal_accuracy(y_test, y_pred_gini) 
      
    print("Results Using Entropy:") 
    # Prediction using entropy 
    y_pred_entropy = prediction(X_test, clf_entropy) 
    cal_accuracy(y_test, y_pred_entropy)

# %%
# Calling main function 
# if __name__=="__main__": 
#     main()

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn.tree import export_graphviz
import pydotplus

# %%
# !pip install pydotplus

# %%
# !pip install graphviz

# %%
# Separating the target variable 
feature_cols = ['Age','No_Ip_visits','No_Op_visits','Diag_count','Proc_count']#,'Proc_Count','Diag_Count','Lab_Count',]
X = final_BCS18[feature_cols] # Features
Y = final_BCS18.Num # Target variable

# Splitting the dataset into train and test 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 100)

# %%
decisionT1 = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5, min_samples_leaf=100, min_samples_split = 200)
decisionT2 = DecisionTreeClassifier(criterion = 'entropy', max_depth = 7, min_samples_leaf=200, min_samples_split = 500)
decisionT3 = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5, min_samples_leaf=500, min_samples_split = 1000)

# %%
# t = decisionT.fit(X_train, y_train)
clf = decisionT2.fit(X, Y)

# %%
n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
leaf_nodes = []
stack = [(0, -1)]  # seed is the root node id and its parent depth
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1

    # If we have a test node
    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True

      #% n_nodes)
for i in range(n_nodes):
    if is_leaves[i]:
        leaf_nodes.append(i)
        #print("%snode=%s leaf node." % (node_depth[i] * "\t", i))    
#print()
#print(leaf_nodes, ',', 'Length = ', len(leaf_nodes))

# %%
 # To get tree value:
arr=clf.tree_.value

# %%
#median of all the nodes of tree
node_val=[]
for i in leaf_nodes:
    node_val.append(arr[i])
size=len(node_val)
i=0
proportions=[]
while (i<size):
    #print(i)
    p=node_val[i][0][0]
    q=node_val[i][0][1]
    pro= q/(p+q)
    #print(pro)
    proportions.append(pro)
    i=i+1
final_pros=proportions
proportions=np.array(proportions)
tree=np.median(proportions)
tree
# Out:
# 0.23484848484848486

# %%
# tree1_med = 0.2161
# tree2_med = 0.2348
# tree3_med = 0.2167

# %%
proportions[::-1].sort()
# Out:
# array([0.9704142 , 0.8705036 , 0.85959885, 0.83854167, 0.82915718,
#        0.79896239, 0.78718259, 0.76680304, 0.71091644, 0.65463918,
#        0.65328467, 0.63228271, 0.61965812, 0.5902965 , 0.56504599,
#        0.52666667, 0.47122302, 0.41642229, 0.3880597 , 0.38292011,
#        0.35292072, 0.32432432, 0.28493211, 0.28095238, 0.2593819 ,
#        0.25193798, 0.24679487, 0.2393273 , 0.23484848, 0.21721311,
#        0.21343874, 0.19318182, 0.18360656, 0.17391304, 0.15953307,
#        0.14006515, 0.13100437, 0.1255814 , 0.10236887, 0.09462916,
#        0.09373382, 0.08444344, 0.07668649, 0.07317073, 0.07257525,
#        0.06189865, 0.06046512, 0.02752294, 0.02743902, 0.01135191,
#        0.00961538, 0.00422833, 0.00359712, 0.        , 0.        ,
#        0.        , 0.        ])

# %%
v1, v2, v3=proportions[[0,1,2]]
i1, i2, i3=final_pros.index(v1), final_pros.index(v2), final_pros.index(v3)
print(v1, ':', i1,'\n',v2,':',i2,'\n',v3,':',i3)
# Out:
# 0.9704142011834319 : 1
#  0.8705035971223022 : 2
#  0.8595988538681948 : 9

# %%
e1, e2,e3=leaf_nodes[i1], leaf_nodes[i2], leaf_nodes[i3]
print(e1, e2, e3)
# Out:
# 8 9 21

# %%
def find_path(node_numb, path, x):
        path.append(node_numb)
        if node_numb == x:
            return True
        left = False
        right = False
        if (children_left[node_numb] !=-1):
            left = find_path(children_left[node_numb], path, x)
        if (children_right[node_numb] !=-1):
            right = find_path(children_right[node_numb], path, x)
        if left or right :
            return True
        path.remove(node_numb)
        return False


def get_rule(path, column_names):
    mask = ''
    for index, node in enumerate(path):
        #We check if we are not in the leaf
        if index!=len(path)-1:
            # Do we go under or over the threshold ?
            if (children_left[node] == path[index+1]):
                mask += "(df['{}']<= {}) \t ".format(column_names[feature[node]], threshold[node])
            else:
                mask += "(df['{}']> {}) \t ".format(column_names[feature[node]], threshold[node])
    # We insert the & at the right places
    mask = mask.replace("\t", "&", mask.count("\t") - 1)
    mask = mask.replace("\t", "")
    return mask

# %%
# Leaves
leave_id = clf.apply(X)

paths ={}
for leaf in np.unique(leave_id):
    path_leaf = []
    find_path(0, path_leaf, leaf)
    paths[leaf] = np.unique(np.sort(path_leaf))

rules = {}
for key in paths:
    rules[key] = get_rule(paths[key], X.columns)

# %%
# rules[2]
print(rules[e1])
print(rules[e2])
print(rules[e3])
# Out:
# (df['Proc_count']<= 0.5) & (df['Diag_count']> 0.5) & (df['No_Op_visits']<= 5.5) & (df['No_Op_visits']<= 4.5) & (df['Diag_count']<= 11.5) & (df['No_Op_visits']<= 2.5) & (df['Diag_count']<= 4.5)
# (df['Proc_count']<= 0.5) & (df['Diag_count']> 0.5) & (df['No_Op_visits']<= 5.5) & (df['No_Op_visits']<= 4.5) & (df['Diag_count']<= 11.5) & (df['No_Op_visits']<= 2.5) & (df['Diag_count']> 4.5)
# (df['Proc_count']<= 0.5) & (df['Diag_count']> 0.5) & (df['No_Op_visits']<= 5.5) & (df['No_Op_visits']> 4.5) & (df['Age']<= 56.5)

# %%
# df=final_BCS19
final_BCS19[eval(rules[e1])]
# Out:
#         MemID  Num  Gender  Age  No_Ip_visits  No_Op_visits  Diag_count  \
# 1542   100359    0       2   75             1             2           2
# 2080   102327    1       2   67             2             2           1
# 3987   108923    1       2   59             1             2           2
# 4118   109337    1       2   72             1             2           4
# 4992   112290    0       2   74             2             2           4
# 7135   119787    1       2   74             1             2           3
# 7345   120563    1       2   70             2             2           4
# 8570   124706    0       2   72             1             2           4
# 8573   124734    1       2   57             1             2           2
# 9150   126743    0       2   70             1             2           2
# 9435   127741    1       2   76             2             2           4
# 9879   129293    1       2   67             1             2           2
# ...

# %%
def f1(df):
    if eval(rules[e1]):
        val = 1
    else:
        val = 0
    return val

def f2(df):
    if eval(rules[e2]):
        val = 1
    else:
        val = 0
    return val

def f3(df):
    if eval(rules[e3]):
        val = 1
    else:
        val = 0
    return val

# %%
final_BCS19['set1'] = final_BCS19.apply(f1, axis=1)
final_BCS19['set2'] = final_BCS19.apply(f2, axis=1)
final_BCS19['set3'] = final_BCS19.apply(f3, axis=1)

# %%
print(len(final_BCS19.index))
print(final_BCS19.Num.sum())
print(final_BCS19.set1.sum())
print(final_BCS19.set2.sum())
print(final_BCS19.set3.sum())
# Out:
# 19545
# 11719
# 16
# 49
# 44

# %%
hitrate=round(final_BCS19.Num.sum()/len(final_BCS19.index),3)
hitrate1=round(final_BCS19.set1.sum()/len(final_BCS19.index),3)
hitrate2=round(final_BCS19.set2.sum()/len(final_BCS19.index),3)
hitrate3=round(final_BCS19.set3.sum()/len(final_BCS19.index),3)
print(hitrate,hitrate1,hitrate2,hitrate3,(hitrate1+hitrate2+hitrate3)/3)
# Out:
# 0.6 0.001 0.003 0.002 0.002

# %%
hitrate1=final_BCS19.Num.sum()/len(final_BCS19.index)
hitrate1

# %%
hitrate1=final_BCS19.Num.sum()/len(final_BCS19.index)
hitrate1

# %%
plt.figure(figsize=(50,25))
a=plot_tree(clf, feature_names=X.columns, class_names= ['0', '1'], filled=True,rounded=True, fontsize=14)
print(a)
# Out:
# [Text(1193.1952247191011, 1274.0625, 'Proc_count <= 0.5\nentropy = 0.778\nsamples = 63353\nvalue = [48771, 14582]\nclass = 0'), Text(603.4550561797753, 1104.1875, 'Diag_count <= 0.5\nentropy = 0.896\nsamples = 12122\nvalue = [3790, 8332]\nclass = 1'), Text(572.1067415730338, 934.3125, 'entropy = 0.0\nsamples = 641\nvalue = [641, 0]\nclass = 0'), Text(634.8033707865169, 934.3125, 'No_Op_visits <= 5.5\nentropy = 0.848\nsamples = 11481\nvalue = [3149, 8332]\nclass = 1'), Text(423.2022471910113, 764.4375, 'No_Op_visits <= 4.5\nentropy = 0.807\nsamples = 10057\nvalue = [2490, 7567]\nclass = 1'), Text(250.7865168539326, 594.5625, 'Diag_count <= 11.5\nentropy = 0.86\nsamples = 6519\nvalue = [1849, 4670]\nclass = 1'), Text(125.3932584269663, 424.6875, 'No_Op_visits <= 2.5\nentropy = 0.733\nsamples = 2993\nvalue = [615, 2378]\nclass = 1'), Text(62.69662921348315, 254.8125, 'Diag_count <= 4.5\nentropy = 0.442\nsamples = 894\nvalue = [82, 812]\nclass = 1'), Text(31.348314606741575, 84.9375, 'en
# ...

# %%
# # Export as dot file
# dot_data = StringIO()
# tree.export_graphviz(t, feature_names = X.columns.values, out_file=dot_data)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# colors = ('turquoise', 'orange')
# Image(graph.create_png())
