# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://lzz55827:931%5Efn5r8jd98f5z@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: lzz55827@BLUDB'

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA='LZZ55827'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('LZZ55827', 'EMPLOYEES', datetime.datetime(2019, 3, 5, 12, 22, 18, 342915)),
#  ('LZZ55827', 'JOB_HISTORY', datetime.datetime(2019, 3, 5, 12, 22, 18, 580426)),
#  ('LZZ55827', 'JOBS', datetime.datetime(2019, 3, 5, 12, 22, 18, 716829)),
#  ('LZZ55827', 'DEPARTMENTS', datetime.datetime(2019, 3, 5, 12, 22, 18, 862138)),
#  ('LZZ55827', 'LOCATION', datetime.datetime(2019, 3, 5, 12, 22, 18, 995734)),
#  ('LZZ55827', 'CHICAGO_SOCIOECONOMIC', datetime.datetime(2019, 3, 16, 12, 53, 9, 575329)),
#  ('LZZ55827', 'INSTRUCTOR', datetime.datetime(2019, 3, 11, 5, 31, 42, 710446)),
#  ('LZZ55827', 'PETSALE', datetime.datetime(2019, 3, 6, 6, 44, 22, 873898)),
#  ('LZZ55827', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2019, 3, 15, 10, 27, 2, 248177)),
#  ('LZZ55827', 'CHICAGO_SCHOOL_REPORTS', datetime.datetime(2019, 3, 16, 3, 54, 58, 104891))]

# %%
# %sql select count(*) AS NO_OF_COLUMNS from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_SCHOOL_REPORTS'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('78'),)]

# %%
# Finding column type and length

# %sql select tabname, colname, typename, scale, default, nulls, identity, generated, remarks, keyseq from syscat.columns where tabname = 'CHICAGO_SCHOOL_REPORTS'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CHICAGO_SCHOOL_REPORTS', 'Net_Change_PLAN_and_ACT', 'VARCHAR', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'College_Eligibility__', 'VARCHAR', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'Graduation_Rate__', 'VARCHAR', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'College_Enrollment_Rate__', 'VARCHAR', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'COLLEGE_ENROLLMENT', 'SMALLINT', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'General_Services_Route', 'SMALLINT', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'Freshman_on_Track_Rate__', 'VARCHAR', 0, None, 'Y', 'N', ' ', None, None),
#  ('CHICAGO_SCHOOL_REPORTS', 'X_COORDINATE', 'DECIMAL', 3, None, 'Y', 'N', ' ', None, None),
# ...

# %%
# %sql select Community_area_name from syscat.columns where colname = 'community_area_name'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "COMMUNITY_AREA_NAME" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: "select Community_area_name from syscat.columns where colname = 'community_area_name'"] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql select count(*) AS NO_OF_ELEMENTARY_SCHOOLS FROM CHICAGO_SCHOOL_REPORTS WHERE "Elementary, Middle, or High School" = 'ES'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('462'),)]

# %%
# %sql select max(Safety_Score) AS max_safety_score from CHICAGO_SCHOOL_REPORTS
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(99,)]

# %%
# %sql select name_of_school, Average_Student_Attendance from CHICAGO_SCHOOL_REPORTS order by average_student_attendance DESC nulls last LIMIT 10
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
# %sql select name_of_school, Average_Student_Attendance from CHICAGO_SCHOOL_REPORTS order by average_student_attendance limit 5
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# %sql select name_of_school, REPLACE(Average_Student_Attendance,'%','') from CHICAGO_SCHOOL_REPORTS order by average_student_attendance limit 5
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
# %sql select name_of_school, Average_Student_Attendance from CHICAGO_SCHOOL_REPORTS where average_student_attendance < '70%'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Dyett High School', '62.50%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Roberto Clemente Community Academy High School', '69.60%'),
#  ('Wendell Phillips Academy High School', '63.00%')]

# %%
# %sql select community_area_name, SUM(college_enrollment) AS TOTAL_ENROLLMENT from CHICAGO_SCHOOL_REPORTS GROUP BY community_area_name
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
# ...

# %%
# %sql select community_area_name, SUM(college_enrollment) AS TOTAL_ENROLLMENT from CHICAGO_SCHOOL_REPORTS GROUP BY community_area_name ORDER BY total_enrollment limit 5
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# %sql select c.community_area_name, s.hardship_index from CHICAGO_SCHOOL_REPORTS AS c, CHICAGO_SOCIOECONOMIC AS s where c.community_area_number = s.community_area_number and college_enrollment = '4638'
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# []

# %%
# %sql select c.community_area_name, c.college_enrollment, s.hardship_index from CHICAGO_SCHOOL_REPORTS AS c, CHICAGO_SOCIOECONOMIC AS s where c.community_area_number = s.community_area_number order by college_enrollment desc limit 1
# Out:
#  * ibm_db_sa://lzz55827:***@dashdb-txn-sbox-yp-lon02-01.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('NORTH CENTER', 4368, 6)]
